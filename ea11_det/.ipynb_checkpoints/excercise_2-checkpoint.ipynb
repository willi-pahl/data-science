# %%
import numpy as np
import pandas as pd

from sklearn import tree

import graphviz

# %%
path = './data/features_data.csv'
features = pd.read_csv(path)
features.head()
# Out:
#    Age  income  student  credit_rating
# 0   30       3        0              1
# 1   30       3        0              2
# 2   31       3        0              1
# 3   41       2        0              1
# 4   41       1        1              1

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            20 non-null     int64
#  1   income         20 non-null     int64
#  2   student        20 non-null     int64
#  3   credit_rating  20 non-null     int64
# dtypes: int64(4)
# memory usage: 768.0 bytes

# %%
path = './data/target_data.csv'
target = pd.read_csv(path)
target.head()
# Out:
#    buys_computer
# 0              0
# 1              0
# 2              1
# 3              1
# 4              1

# %%
target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   buys_computer  20 non-null     int64
# dtypes: int64(1)
# memory usage: 288.0 bytes

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(features, target)
tree.plot_tree(clf)
# Out:
# [Text(0.36363636363636365, 0.9166666666666666, 'X[0] <= 30.5\ngini = 0.48\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.18181818181818182, 0.75, 'X[2] <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.09090909090909091, 0.5833333333333334, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.2727272727272727, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5454545454545454, 0.75, 'X[0] <= 36.0\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.45454545454545453, 0.5833333333333334, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6363636363636364, 0.5833333333333334, 'X[3] <= 1.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.5454545454545454, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7272727272727273, 0.4166666666666667, 'X[2] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6363636363636364, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8181818181818182, 0.25, 'X[1] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7272727272727273, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9090909090909091, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("buys_compute")
# Out:
# 'buys_compute.pdf'

# %%
features
# Out:
#     Age  income  student  credit_rating
# 0    30       3        0              1
# 1    30       3        0              2
# 2    31       3        0              1
# 3    41       2        0              1
# 4    41       1        1              1
# 5    41       1        1              2
# 6    31       1        1              2
# 7    30       2        0              1
# 8    30       1        1              1
# 9    41       2        1              1
# 10   30       2        1              2
# 11   31       2        0              2
# 12   31       3        1              1
# 13   41       2        0              2
# 14   30       2        0              2
# 15   30       1        0              1
# 16   30       1        0              2
# 17   31       1        1              1
# 18   41       2        1              2
# 19   31       3        0              2

# %%
dot_data = tree.export_graphviz(
    clf,
    out_file=None, 
    feature_names=['age','income','student','credit'],  
    class_names=['YES', 'NO'],  
    filled=True, 
    rounded=True,  
    special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
